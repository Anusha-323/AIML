# %%
this_list=["apple","melon","date","grape","sapota"]
print(this_list)
# Out:
# ['apple', 'melon', 'date', 'grape', 'sapota']

# %%
thislist=["apple","banana","cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
temp=70
celsius=(temp-32)*5/9
print(celsius)
# Out:
# 21.11111111111111

# %%
def fahrenhit_to_celsius(fahrenhit):
  return(farhrenhit-32)*5/9

  print(fahrenhit_to_celsius(70))
  print(fahrenhit_to_celius(90))

# %%
list1=["apple","banana","cherry","grape","apple"]
list2=["1,7,5,9,0"]
list3=[True,False,True,True]
print(list1)
print(list2)
print(list3)
range(len(list1))
# Out:
# ['apple', 'banana', 'cherry', 'grape', 'apple']
# ['1,7,5,9,0']
# [True, False, True, True]
# range(0, 5)

# %%
list1=["rice","wheat","maize","pulse"]
range(len(list1))

# %%
original_list=[50,60,100,50,90]
reversed_iterator=reversed(original_list)
reversed_list=list(reversed_iterator)
print(reversed_list)
